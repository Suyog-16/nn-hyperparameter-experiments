# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Learning Rate vs Average Loss and Accuracy

# %%
df_learning_rate = pd.read_csv("results/learning_rates.csv")
df_learning_rate
# Out:
#    Unnamed: 0  Learning Rate  Accuracy  Average Loss
# 0           0          0.001     72.02      1.592877
# 1           1          0.010     92.40      0.271282
# 2           2          0.100     97.51      0.078680
# 3           3          0.500     97.81      0.074502
# 4           4          0.900     97.90      0.085150

# %%
plt.figure(figsize=(8,5))
plt.plot(df_learning_rate['Learning Rate'],df_learning_rate['Average Loss'],color = 'red')
plt.title("Learning Rate vs Average Loss")
plt.xlabel("Learning Rate")
plt.ylabel("Average loss")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df_learning_rate['Learning Rate'],df_learning_rate['Accuracy'],color = 'red')
plt.title("Learning Rate vs Accuracy")

plt.xlabel("Learning Rate")
plt.ylabel("Accuracy")
plt.xticks([0.001,0.1,0.2,0.5,0.9])
plt.show()

# %% [markdown]
# ### Batch Size vs Average Loss and Accuracy

# %%
df_batch = pd.read_csv("results/batch_size.csv")
df_batch
# Out:
#    Unnamed: 0  Batch  Accuracy  Average Loss
# 0           0     28     86.28      0.558092
# 1           1     64     72.02      1.592877
# 2           2    128     63.44      2.145701
# 3           3    256     50.94      2.243278
# 4           4    512     30.77      2.275239

# %%
plt.figure(figsize=(8,5))
plt.plot(df_batch['Batch'],df_batch['Accuracy'],color = 'red')
plt.title("Batch Sizes vs Accuracy")
plt.xlabel("Batch Sizes")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df_batch['Batch'],df_batch['Average Loss'],color = 'red')
plt.title("Batch Sizes vs Average Loss")
plt.xlabel("Batch Sizes")
plt.ylabel("Avg Loss")
plt.show()

# %% [markdown]
# ### Optimizer vs Average Loss and Accuracy

# %%
df_optimizer = pd.read_csv("results/optimizer.csv")
df_optimizer
# Out:
#    Unnamed: 0 Optimizer  Accuracy  Average Loss
# 0           0       SGD     72.02      1.592877
# 1           1      Adam     97.73      0.079857
# 2           2   RMSprop     98.06      0.086459
# 3           3   Adagrad     94.00      0.208347

# %%
plt.figure(figsize=(8,5))
plt.plot(df_optimizer['Optimizer'],df_optimizer['Accuracy'],color = 'red')
plt.title("Optimizer vs Accuracy")
plt.xlabel("Optimizer")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df_optimizer['Optimizer'],df_optimizer['Average Loss'],color = 'red')
plt.title("Optimizer vs Average Loss")
plt.xlabel("Optimizer")
plt.ylabel("Avg Loss")
plt.show()

# %% [markdown]
# ### Epochs count vs Average Loss and Accuracy

# %%
df_epochs = pd.read_csv("results/epochs.csv")
df_epochs
# Out:
#    Unnamed: 0  Epoch Count  Accuracy  Average Loss
# 0           0            5     72.02      1.592877
# 1           1           10     85.18      0.636826
# 2           2           20     89.45      0.381543
# 3           3           50     92.26      0.271062

# %%
plt.figure(figsize=(8,5))
plt.plot(df_epochs['Epoch Count'],df_epochs['Accuracy'],color = 'red')
plt.title("Epoch vs Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xticks([5,10,20,50])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df_epochs['Epoch Count'],df_epochs['Average Loss'],color = 'red')
plt.title("Epoch vs Average Loss")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.xticks([5,10,20,50])
plt.show()
